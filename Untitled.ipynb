# %%
from IPython.display import Image

# %%
display(Image(filename='dress.jpeg', width=200))

# %%
from extract_features import get_vector
# Out:
# Downloading: "https://download.pytorch.org/models/resnet18-5c106cde.pth" to /root/.cache/torch/checkpoints/resnet18-5c106cde.pth
# 100%|██████████| 44.7M/44.7M [00:02<00:00, 18.5MB/s]

# %%
vec = get_vector('dress.jpeg')
# Out:
# /opt/conda/lib/python3.6/site-packages/torch/tensor.py:293: UserWarning: non-inplace resize is deprecated
#   warnings.warn("non-inplace resize is deprecated")

# %%
vec[:2]
# Out:
# array([0.27841428, 1.6626568 ], dtype=float32)

# %%
vec.shape
# Out:
# (512,)

# %% [markdown]
# # Speed testing. CPU vs GPU

# %%
"""Feature Extraction from Image Filename."""

from PIL import Image
import torch
from torch.autograd import Variable
import torchvision.models as models
import torchvision.transforms as transforms

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
model = models.resnet18(pretrained=True)
model.to(device).eval()

layer = model._modules.get('avgpool')

scaler = transforms.Resize((224, 224))
normalize = transforms.Normalize(mean=[0.485, 0.456, 0.406],
                                 std=[0.229, 0.224, 0.225])
to_tensor = transforms.ToTensor()
img = Image.open('dress.jpeg')
t_img = Variable(normalize(to_tensor(scaler(img))).unsqueeze(0))

def get_vector(t_img):
    """Extract vector from filename for local image."""
#     img = Image.open(image_name)
#     t_img = Variable(normalize(to_tensor(scaler(img))).unsqueeze(0))
    t_img = t_img.to(device)

    # Create hook to extract vector
    embedding = torch.zeros(512)

    def copy_data(m, i, o):
        embedding.copy_(o.data.resize(512))
    h = layer.register_forward_hook(copy_data)

    model(t_img)
    h.remove()

    if device.type == 'cuda':
        embedding = embedding.cpu()
    return embedding.numpy()

# %%
from extract_features_compute_agnostic import get_vector

# %%
# %timeit get_vector('dress.jpeg')
# Out:
# 29.8 ms ± 2.63 ms per loop (mean ± std. dev. of 7 runs, 10 loops each)
